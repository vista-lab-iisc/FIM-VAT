# %%
from FIM_VAT import FIM_VAT
import datasets

# %% [markdown]
# # IRIS

# %%
X,y = datasets.iris(2)
iris = FIM_VAT(X)
iris.explainer("IRIS")

# %% [markdown]
# # WINE

# %%
X,y = datasets.wine(2)
wine = FIM_VAT(X)
wine.explainer("WINE")

# %% [markdown]
# # SEEDS

# %%
X,y = datasets.seeds(2)
seeds = FIM_VAT(X)
seeds.explainer("SEEDS")

# %% [markdown]
# # VOTING

# %%
X,y = datasets.voting()
voting = FIM_VAT(X)
voting.explainer("VOTING")

# %% [markdown]
# # GLASS

# %%
X,y = datasets.glass(2)
glass = FIM_VAT(X)
glass.explainer("GLASS")

# %% [markdown]
# # CERAMIC

# %%
X,y = datasets.ceramic(2)
ceramic = FIM_VAT(X)
ceramic.explainer("CERAMIC")
